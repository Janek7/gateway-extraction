# %%
# add parent dir to sys path for import of modules
import json
import os
import sys
# find recursively the project root dir
parent_dir = str(os.getcwdb())
while not os.path.exists(os.path.join(parent_dir, "README.md")):
    parent_dir = os.path.abspath(os.path.join(parent_dir, os.pardir))
sys.path.insert(0, parent_dir)

# %%
from PetReader import pet_reader
from petreader import labels
from petreader.labels import *
from utils import ROOT_DIR
# Out:
# INFO:Utilities:Loaded config: {'general-seed': 42, 'keywords-filtered-approach': {'bert-model-name': 'distilbert-base-uncased', 'label-set': 'all', 'label-number': 9, 'other-labels-weight': 0.1, 'num-labels': 9}, 'same-gateway-classifier': {'context_label_length': 350}, 'synonym-samples-start-number': 500}
# INFO:PetReader:Reload pet_reader from C:\Users\janek\Development\Git\master-thesis\data/other/pet_reader.pkl

# %% [markdown]
# ## Single Doc

# %%
def print_doc_details(doc_name):
    print(" TEXT ".center(100, '-'))
    for i, s in enumerate(pet_reader.get_doc_sentences(doc_name)):
        print(i, ' '.join(s))
    print()


    print(" ACTIVITIES ".center(100, '-'))
    for i, a in enumerate(pet_reader.token_dataset.GetActivities(doc_name)):
        print(i, a)
    print()

    print(" XOR GATEWAYS ".center(100, '-'))
    for i, gs in enumerate(pet_reader.token_dataset.GetXORGateways(doc_name)):
        if gs: 
            print(i, gs)
    print()

    print(" AND GATEWAYS ".center(100, '-'))
    for i, gs in enumerate(pet_reader.token_dataset.GetANDGateways(doc_name)):
        if gs:
            print(i, gs)
    print()

    
    doc_relations = pet_reader.relations_dataset.GetRelations(pet_reader.get_document_number(doc_name))
    doc_flow_relations, doc_same_gateway_relations = doc_relations[labels.FLOW], doc_relations[labels.SAME_GATEWAY]
    print(" SAME GATEWAY RELATION ".center(100, '-'))
    for i, same_gateway_relation in enumerate(doc_same_gateway_relations):
        for key, value in same_gateway_relation.items():
            print(f"{key}: {value}")
        print()
    print(" FLOW RELATION ".center(100, '-'))
    for i, flow_relation in enumerate(doc_flow_relations):
        for key, value in flow_relation.items():
            print(f"{key}: {value}")
        print()

# %%
list(sorted(pet_reader.document_names))
# Out:
# ['doc-1.1',
#  'doc-1.2',
#  'doc-1.3',
#  'doc-1.4',
#  'doc-10.1',
#  'doc-10.10',
#  'doc-10.11',
#  'doc-10.12',
#  'doc-10.13',
#  'doc-10.14',
#  'doc-10.2',
#  'doc-10.3',
#  'doc-10.4',
#  'doc-10.5',
#  'doc-10.6',
#  'doc-10.7',
#  'doc-10.8',
#  'doc-10.9',
#  'doc-2.1',
#  'doc-2.2',
#  'doc-3.1',
#  'doc-3.2',
#  'doc-3.3',
#  'doc-3.5',
#  'doc-3.6',
#  'doc-3.7',
#  'doc-3.8',
#  'doc-4.1',
#  'doc-5.1',
#  'doc-5.2',
#  'doc-5.3',
#  'doc-5.4',
#  'doc-6.1',
#  'doc-6.2',
#  'doc-6.3',
#  'doc-6.4',
#  'doc-7.1',
#  'doc-8.1',
#  'doc-8.2',
#  'doc-8.3',
#  'doc-9.1',
#  'doc-9.2',
#  'doc-9.3',
#  'doc-9.4',
#  'doc-9.5']

# %%
print_doc_details('doc-2.2')
# Out:
# ----------------------------------------------- TEXT -----------------------------------------------
# 0 The process is initiated by a switch-over request .
# 1 In doing so , the customer transmits his data to the customer service department of the company .
# 2 Customer service is a shared service center between the departments Sales and Distribution .
# 3 The customer data is received by customer service and based on this data a customer data object is entered into the CRM system .
# 4 After customer data has been entered it should then be compared with the internal customer data base and checked for completeness and plausibility .
# 5 In case of any errors these should be corrected on the basis of a simple error list .
# 6 The comparison of data is done to prevent individual customer data being stored multiple times .
# 7 In case the customer does not exist in the customer data base , a new customer object is being created which will remain the data object of interest during the rest of the process flow .
# 8 This object consists of data elements such as the customer's name and address and the assigned power gauge .
# 9 The generated customer object is then used , in combination with other customer data to prepare the contract documents for the power supplier switch ( including data such as bank connection , information on the selected rate , requested date of switch-over ) .
# 10 In the following an automated check of the contract documents is carried out within the CIS ( customer information system ) in order to confirm their successful generation .
# 11 In case of a negative response , i.e . the contract documents are not ( or incorrectly ) generated , the causing issues are being analyzed and resolved .
# 12 Subsequently the contract documents are generated once again .
# 13 In case of a positive response a confirmation document is sent out to the customer stating that the switch-over to the new supplier can be executed .
# 14 A request to the grid operator is automatically sent out by the CIS .
# 15 It puts the question whether the customer may be supplied by the selected supplier in the future .
# 16 The switch-over request is checked by the grid operator for supplier concurrence , and the grid operator transmits a response comment .
# 17 In the case of supplier concurrence the grid operator would inform all involved suppliers and demand the resolution of the conflict .
# 18 The grid operator communicates with the old supplier and carries out the termination of the sales agreement between the customer and the old supplier ( i.e . the customer service ( of the new supplier ) does not have to interact with the old supplier regarding termination ) .
# 19 If there are not any objections by the grid operator ( i.e . no supplier concurrence ) , customer service creates a CIS contract .
# 20 The customer then has the chance to check the contract details and based on this check may decide to either withdraw from the switch contract or confirm it .
# 21 Depending on the customer's acceptance / rejection the process flow at customer service either ends ( in case of withdrawal ) or continues ( in case of a confirmation ) .
# 22 An additional constraint is that the customer can only withdraw from the offered contract within 7 days after the 7th day the contract will be regarded as accepted and the process continues .
# 23 The confirmation message by the customer is therefore not absolutely necessary ( as it will count as accepted after 7 days in any way ) but it can speed up the switch process .
# 24 On the switch-date , but no later than 10 days after power supply has begun , the grid operator transmits the power meter data to the customer service and the old supplier via messages containing a services consumption report .
# 25 At the same time , the grid operator computes the final billing based on the meter data and sends it to the old supplier .
# 26 Likewise the old supplier creates and sends the final billing to the customer .
# 27 For the customer as well as the grid operator the process ends then .
# 28 After receiving the meter data customer service imports the meter data to systems that require the information .
# 29 The process of winning a new customer ends here .
#
# -------------------------------------------- ACTIVITIES --------------------------------------------
# 0 []
# 1 [['transmits']]
# 2 []
# 3 [['received'], ['entered']]
# 4 [['compared'], ['checked']]
# 5 [['corrected']]
# 6 []
# 7 [['created']]
# 8 []
# 9 [['prepare']]
# 10 [['check']]
# 11 [['analyzed'], ['resolved']]
# 12 [['generated']]
# 13 [['sent', 'out']]
# 14 [['sent', 'out']]
# 15 []
# 16 [['checked'], ['transmits']]
# 17 [['inform'], ['demand']]
# 18 [['communicates'], ['carries', 'out']]
# 19 [['creates']]
# 20 [['check'], ['withdraw'], ['confirm']]
# 21 []
# 22 []
# 23 []
# 24 [['transmits']]
# 25 [['computes'], ['sends']]
# 26 [['creates'], ['sends']]
# 27 []
# 28 [['receiving'], ['imports']]
# 29 []
#
# ------------------------------------------- XOR GATEWAYS -------------------------------------------
# 5 [['In', 'case', 'of']]
# 7 [['In', 'case']]
# 11 [['In', 'case', 'of']]
# 13 [['In', 'case', 'of']]
# 17 [['In', 'the', 'case', 'of']]
# 19 [['If']]
# 20 [['either'], ['or']]
#
# ------------------------------------------- AND GATEWAYS -------------------------------------------
# 25 [['At', 'the', 'same', 'time']]
#
# -------------------------------------- SAME GATEWAY RELATION ---------------------------------------
# source-head-sentence-ID: 11
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['In', 'case', 'of']
# target-head-sentence-ID: 13
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['In', 'case', 'of']
#
# source-head-sentence-ID: 17
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['In', 'the', 'case', 'of']
# target-head-sentence-ID: 19
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['If']
#
# source-head-sentence-ID: 20
# source-head-word-ID: 19
# source-entity-type: XOR Gateway
# source-entity: ['either']
# target-head-sentence-ID: 20
# target-head-word-ID: 25
# target-entity-type: XOR Gateway
# target-entity: ['or']
#
# ------------------------------------------ FLOW RELATION -------------------------------------------
# source-head-sentence-ID: 1
# source-head-word-ID: 6
# source-entity-type: Activity
# source-entity: ['transmits']
# target-head-sentence-ID: 3
# target-head-word-ID: 4
# target-entity-type: Activity
# target-entity: ['received']
#
# source-head-sentence-ID: 3
# source-head-word-ID: 4
# source-entity-type: Activity
# source-entity: ['received']
# target-head-sentence-ID: 3
# target-head-word-ID: 18
# target-entity-type: Activity
# target-entity: ['entered']
#
# source-head-sentence-ID: 3
# source-head-word-ID: 18
# source-entity-type: Activity
# source-entity: ['entered']
# target-head-sentence-ID: 4
# target-head-word-ID: 10
# target-entity-type: Activity
# target-entity: ['compared']
#
# source-head-sentence-ID: 4
# source-head-word-ID: 10
# source-entity-type: Activity
# source-entity: ['compared']
# target-head-sentence-ID: 4
# target-head-word-ID: 18
# target-entity-type: Activity
# target-entity: ['checked']
#
# source-head-sentence-ID: 4
# source-head-word-ID: 18
# source-entity-type: Activity
# source-entity: ['checked']
# target-head-sentence-ID: 5
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['In', 'case', 'of']
#
# source-head-sentence-ID: 5
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['In', 'case', 'of']
# target-head-sentence-ID: 5
# target-head-word-ID: 3
# target-entity-type: Condition Specification
# target-entity: ['any', 'errors']
#
# source-head-sentence-ID: 5
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['In', 'case', 'of']
# target-head-sentence-ID: 7
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['In', 'case']
#
# source-head-sentence-ID: 5
# source-head-word-ID: 3
# source-entity-type: Condition Specification
# source-entity: ['any', 'errors']
# target-head-sentence-ID: 5
# target-head-word-ID: 8
# target-entity-type: Activity
# target-entity: ['corrected']
#
# source-head-sentence-ID: 5
# source-head-word-ID: 8
# source-entity-type: Activity
# source-entity: ['corrected']
# target-head-sentence-ID: 7
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['In', 'case']
#
# source-head-sentence-ID: 7
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['In', 'case']
# target-head-sentence-ID: 7
# target-head-word-ID: 2
# target-entity-type: Condition Specification
# target-entity: ['the', 'customer', 'does', 'not', 'exist', 'in', 'the', 'customer', 'data', 'base']
#
# source-head-sentence-ID: 7
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['In', 'case']
# target-head-sentence-ID: 10
# target-head-word-ID: 5
# target-entity-type: Activity
# target-entity: ['check']
#
# source-head-sentence-ID: 7
# source-head-word-ID: 2
# source-entity-type: Condition Specification
# source-entity: ['the', 'customer', 'does', 'not', 'exist', 'in', 'the', 'customer', 'data', 'base']
# target-head-sentence-ID: 7
# target-head-word-ID: 19
# target-entity-type: Activity
# target-entity: ['created']
#
# source-head-sentence-ID: 7
# source-head-word-ID: 19
# source-entity-type: Activity
# source-entity: ['created']
# target-head-sentence-ID: 9
# target-head-word-ID: 15
# target-entity-type: Activity
# target-entity: ['prepare']
#
# source-head-sentence-ID: 9
# source-head-word-ID: 15
# source-entity-type: Activity
# source-entity: ['prepare']
# target-head-sentence-ID: 10
# target-head-word-ID: 5
# target-entity-type: Activity
# target-entity: ['check']
#
# source-head-sentence-ID: 10
# source-head-word-ID: 5
# source-entity-type: Activity
# source-entity: ['check']
# target-head-sentence-ID: 11
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['In', 'case', 'of']
#
# source-head-sentence-ID: 11
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['In', 'case', 'of']
# target-head-sentence-ID: 11
# target-head-word-ID: 3
# target-entity-type: Condition Specification
# target-entity: ['a', 'negative', 'response']
#
# source-head-sentence-ID: 11
# source-head-word-ID: 3
# source-entity-type: Condition Specification
# source-entity: ['a', 'negative', 'response']
# target-head-sentence-ID: 11
# target-head-word-ID: 25
# target-entity-type: Activity
# target-entity: ['analyzed']
#
# source-head-sentence-ID: 11
# source-head-word-ID: 25
# source-entity-type: Activity
# source-entity: ['analyzed']
# target-head-sentence-ID: 11
# target-head-word-ID: 27
# target-entity-type: Activity
# target-entity: ['resolved']
#
# source-head-sentence-ID: 11
# source-head-word-ID: 27
# source-entity-type: Activity
# source-entity: ['resolved']
# target-head-sentence-ID: 12
# target-head-word-ID: 5
# target-entity-type: Activity
# target-entity: ['generated']
#
# source-head-sentence-ID: 12
# source-head-word-ID: 5
# source-entity-type: Activity
# source-entity: ['generated']
# target-head-sentence-ID: 10
# target-head-word-ID: 5
# target-entity-type: Activity
# target-entity: ['check']
#
# source-head-sentence-ID: 13
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['In', 'case', 'of']
# target-head-sentence-ID: 13
# target-head-word-ID: 3
# target-entity-type: Condition Specification
# target-entity: ['a', 'positive', 'response']
#
# source-head-sentence-ID: 13
# source-head-word-ID: 3
# source-entity-type: Condition Specification
# source-entity: ['a', 'positive', 'response']
# target-head-sentence-ID: 13
# target-head-word-ID: 10
# target-entity-type: Activity
# target-entity: ['sent', 'out']
#
# source-head-sentence-ID: 13
# source-head-word-ID: 10
# source-entity-type: Activity
# source-entity: ['sent', 'out']
# target-head-sentence-ID: 14
# target-head-word-ID: 8
# target-entity-type: Activity
# target-entity: ['sent', 'out']
#
# source-head-sentence-ID: 14
# source-head-word-ID: 8
# source-entity-type: Activity
# source-entity: ['sent', 'out']
# target-head-sentence-ID: 16
# target-head-word-ID: 4
# target-entity-type: Activity
# target-entity: ['checked']
#
# source-head-sentence-ID: 16
# source-head-word-ID: 4
# source-entity-type: Activity
# source-entity: ['checked']
# target-head-sentence-ID: 16
# target-head-word-ID: 17
# target-entity-type: Activity
# target-entity: ['transmits']
#
# source-head-sentence-ID: 16
# source-head-word-ID: 17
# source-entity-type: Activity
# source-entity: ['transmits']
# target-head-sentence-ID: 17
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['In', 'the', 'case', 'of']
#
# source-head-sentence-ID: 17
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['In', 'the', 'case', 'of']
# target-head-sentence-ID: 17
# target-head-word-ID: 4
# target-entity-type: Condition Specification
# target-entity: ['supplier', 'concurrence']
#
# source-head-sentence-ID: 17
# source-head-word-ID: 4
# source-entity-type: Condition Specification
# source-entity: ['supplier', 'concurrence']
# target-head-sentence-ID: 17
# target-head-word-ID: 10
# target-entity-type: Activity
# target-entity: ['inform']
#
# source-head-sentence-ID: 17
# source-head-word-ID: 10
# source-entity-type: Activity
# source-entity: ['inform']
# target-head-sentence-ID: 17
# target-head-word-ID: 15
# target-entity-type: Activity
# target-entity: ['demand']
#
# source-head-sentence-ID: 17
# source-head-word-ID: 15
# source-entity-type: Activity
# source-entity: ['demand']
# target-head-sentence-ID: 18
# target-head-word-ID: 3
# target-entity-type: Activity
# target-entity: ['communicates']
#
# source-head-sentence-ID: 18
# source-head-word-ID: 3
# source-entity-type: Activity
# source-entity: ['communicates']
# target-head-sentence-ID: 18
# target-head-word-ID: 9
# target-entity-type: Activity
# target-entity: ['carries', 'out']
#
# source-head-sentence-ID: 19
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 19
# target-head-word-ID: 1
# target-entity-type: Condition Specification
# target-entity: ['there', 'are', 'not', 'any', 'objections', 'by', 'the', 'grid', 'operator']
#
# source-head-sentence-ID: 19
# source-head-word-ID: 1
# source-entity-type: Condition Specification
# source-entity: ['there', 'are', 'not', 'any', 'objections', 'by', 'the', 'grid', 'operator']
# target-head-sentence-ID: 19
# target-head-word-ID: 20
# target-entity-type: Activity
# target-entity: ['creates']
#
# source-head-sentence-ID: 19
# source-head-word-ID: 20
# source-entity-type: Activity
# source-entity: ['creates']
# target-head-sentence-ID: 20
# target-head-word-ID: 7
# target-entity-type: Activity
# target-entity: ['check']
#
# source-head-sentence-ID: 20
# source-head-word-ID: 7
# source-entity-type: Activity
# source-entity: ['check']
# target-head-sentence-ID: 20
# target-head-word-ID: 19
# target-entity-type: XOR Gateway
# target-entity: ['either']
#
# source-head-sentence-ID: 20
# source-head-word-ID: 19
# source-entity-type: XOR Gateway
# source-entity: ['either']
# target-head-sentence-ID: 20
# target-head-word-ID: 20
# target-entity-type: Activity
# target-entity: ['withdraw']
#
# source-head-sentence-ID: 20
# source-head-word-ID: 19
# source-entity-type: XOR Gateway
# source-entity: ['either']
# target-head-sentence-ID: 20
# target-head-word-ID: 25
# target-entity-type: XOR Gateway
# target-entity: ['or']
#
# source-head-sentence-ID: 20
# source-head-word-ID: 25
# source-entity-type: XOR Gateway
# source-entity: ['or']
# target-head-sentence-ID: 20
# target-head-word-ID: 26
# target-entity-type: Activity
# target-entity: ['confirm']
#
# source-head-sentence-ID: 20
# source-head-word-ID: 26
# source-entity-type: Activity
# source-entity: ['confirm']
# target-head-sentence-ID: 24
# target-head-word-ID: 19
# target-entity-type: Activity
# target-entity: ['transmits']
#
# source-head-sentence-ID: 24
# source-head-word-ID: 19
# source-entity-type: Activity
# source-entity: ['transmits']
# target-head-sentence-ID: 25
# target-head-word-ID: 0
# target-entity-type: AND Gateway
# target-entity: ['At', 'the', 'same', 'time']
#
# source-head-sentence-ID: 25
# source-head-word-ID: 0
# source-entity-type: AND Gateway
# source-entity: ['At', 'the', 'same', 'time']
# target-head-sentence-ID: 24
# target-head-word-ID: 19
# target-entity-type: Activity
# target-entity: ['transmits']
#
# source-head-sentence-ID: 25
# source-head-word-ID: 0
# source-entity-type: AND Gateway
# source-entity: ['At', 'the', 'same', 'time']
# target-head-sentence-ID: 25
# target-head-word-ID: 8
# target-entity-type: Activity
# target-entity: ['computes']
#
# source-head-sentence-ID: 25
# source-head-word-ID: 0
# source-entity-type: AND Gateway
# source-entity: ['At', 'the', 'same', 'time']
# target-head-sentence-ID: 26
# target-head-word-ID: 4
# target-entity-type: Activity
# target-entity: ['creates']
#
# source-head-sentence-ID: 25
# source-head-word-ID: 8
# source-entity-type: Activity
# source-entity: ['computes']
# target-head-sentence-ID: 25
# target-head-word-ID: 18
# target-entity-type: Activity
# target-entity: ['sends']
#
# source-head-sentence-ID: 25
# source-head-word-ID: 18
# source-entity-type: Activity
# source-entity: ['sends']
# target-head-sentence-ID: 28
# target-head-word-ID: 1
# target-entity-type: Activity
# target-entity: ['receiving']
#
# source-head-sentence-ID: 26
# source-head-word-ID: 4
# source-entity-type: Activity
# source-entity: ['creates']
# target-head-sentence-ID: 26
# target-head-word-ID: 6
# target-entity-type: Activity
# target-entity: ['sends']
#
# source-head-sentence-ID: 26
# source-head-word-ID: 6
# source-entity-type: Activity
# source-entity: ['sends']
# target-head-sentence-ID: 28
# target-head-word-ID: 1
# target-entity-type: Activity
# target-entity: ['receiving']
#
# source-head-sentence-ID: 28
# source-head-word-ID: 1
# source-entity-type: Activity
# source-entity: ['receiving']
# target-head-sentence-ID: 28
# target-head-word-ID: 7
# target-entity-type: Activity
# target-entity: ['imports']

# %%
print_doc_details('doc-9.5')
# Out:
# ----------------------------------------------- TEXT -----------------------------------------------
# 0 After the Expense Report is received , a new account must be created if the employee does not already have one .
# 1 The report is then reviewed for automatic approval .
# 2 Amounts under $200 are automatically approved , whereas amounts equal to or over $200 require approval of the supervisor .
# 3 In case of rejection , the employee must receive a rejection notice by email .
# 4 Otherwise , the reimbursement goes to the employees direct deposit bank account .
# 5 If the request is not completed in 7 days , then the employee must receive an approval in progress email .
# 6 If the request is not finished within 30 days , then the process is stopped and the employee receives an email cancellation notice and must re-submit the expense report .
#
# -------------------------------------------- ACTIVITIES --------------------------------------------
# 0 [['received'], ['created']]
# 1 [['reviewed']]
# 2 [['approved'], ['require']]
# 3 [['receive']]
# 4 [['goes']]
# 5 [['receive']]
# 6 [['receives'], ['re-submit']]
#
# ------------------------------------------- XOR GATEWAYS -------------------------------------------
# 0 [['if']]
# 2 [['whereas']]
# 3 [['In', 'case', 'of']]
# 4 [['Otherwise']]
# 5 [['If']]
# 6 [['If']]
#
# ------------------------------------------- AND GATEWAYS -------------------------------------------
#
# -------------------------------------- SAME GATEWAY RELATION ---------------------------------------
# source-head-sentence-ID: 3
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['In', 'case', 'of']
# target-head-sentence-ID: 4
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['Otherwise']
#
# source-head-sentence-ID: 4
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['Otherwise']
# target-head-sentence-ID: 5
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['If']
#
# ------------------------------------------ FLOW RELATION -------------------------------------------
# source-head-sentence-ID: 0
# source-head-word-ID: 5
# source-entity-type: Activity
# source-entity: ['received']
# target-head-sentence-ID: 0
# target-head-word-ID: 13
# target-entity-type: XOR Gateway
# target-entity: ['if']
#
# source-head-sentence-ID: 0
# source-head-word-ID: 12
# source-entity-type: Activity
# source-entity: ['created']
# target-head-sentence-ID: 1
# target-head-word-ID: 4
# target-entity-type: Activity
# target-entity: ['reviewed']
#
# source-head-sentence-ID: 0
# source-head-word-ID: 13
# source-entity-type: XOR Gateway
# source-entity: ['if']
# target-head-sentence-ID: 0
# target-head-word-ID: 14
# target-entity-type: Condition Specification
# target-entity: ['the', 'employee', 'does', 'not', 'already', 'have', 'one']
#
# source-head-sentence-ID: 0
# source-head-word-ID: 13
# source-entity-type: XOR Gateway
# source-entity: ['if']
# target-head-sentence-ID: 1
# target-head-word-ID: 4
# target-entity-type: Activity
# target-entity: ['reviewed']
#
# source-head-sentence-ID: 0
# source-head-word-ID: 14
# source-entity-type: Condition Specification
# source-entity: ['the', 'employee', 'does', 'not', 'already', 'have', 'one']
# target-head-sentence-ID: 0
# target-head-word-ID: 12
# target-entity-type: Activity
# target-entity: ['created']
#
# source-head-sentence-ID: 1
# source-head-word-ID: 4
# source-entity-type: Activity
# source-entity: ['reviewed']
# target-head-sentence-ID: 2
# target-head-word-ID: 7
# target-entity-type: XOR Gateway
# target-entity: ['whereas']
#
# source-head-sentence-ID: 2
# source-head-word-ID: 0
# source-entity-type: Condition Specification
# source-entity: ['Amounts', 'under', '$200']
# target-head-sentence-ID: 2
# target-head-word-ID: 5
# target-entity-type: Activity
# target-entity: ['approved']
#
# source-head-sentence-ID: 2
# source-head-word-ID: 7
# source-entity-type: XOR Gateway
# source-entity: ['whereas']
# target-head-sentence-ID: 2
# target-head-word-ID: 8
# target-entity-type: Condition Specification
# target-entity: ['amounts', 'equal', 'to', 'or', 'over', '$200']
#
# source-head-sentence-ID: 2
# source-head-word-ID: 7
# source-entity-type: XOR Gateway
# source-entity: ['whereas']
# target-head-sentence-ID: 2
# target-head-word-ID: 0
# target-entity-type: Condition Specification
# target-entity: ['Amounts', 'under', '$200']
#
# source-head-sentence-ID: 2
# source-head-word-ID: 8
# source-entity-type: Condition Specification
# source-entity: ['amounts', 'equal', 'to', 'or', 'over', '$200']
# target-head-sentence-ID: 2
# target-head-word-ID: 14
# target-entity-type: Activity
# target-entity: ['require']
#
# source-head-sentence-ID: 2
# source-head-word-ID: 14
# source-entity-type: Activity
# source-entity: ['require']
# target-head-sentence-ID: 3
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['In', 'case', 'of']
#
# source-head-sentence-ID: 3
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['In', 'case', 'of']
# target-head-sentence-ID: 3
# target-head-word-ID: 3
# target-entity-type: Condition Specification
# target-entity: ['rejection']
#
# source-head-sentence-ID: 3
# source-head-word-ID: 3
# source-entity-type: Condition Specification
# source-entity: ['rejection']
# target-head-sentence-ID: 3
# target-head-word-ID: 8
# target-entity-type: Activity
# target-entity: ['receive']
#
# source-head-sentence-ID: 4
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['Otherwise']
# target-head-sentence-ID: 4
# target-head-word-ID: 4
# target-entity-type: Activity
# target-entity: ['goes']
#
# source-head-sentence-ID: 5
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 5
# target-head-word-ID: 1
# target-entity-type: Condition Specification
# target-entity: ['the', 'request', 'is', 'not', 'completed', 'in', '7', 'days']
#
# source-head-sentence-ID: 5
# source-head-word-ID: 1
# source-entity-type: Condition Specification
# source-entity: ['the', 'request', 'is', 'not', 'completed', 'in', '7', 'days']
# target-head-sentence-ID: 5
# target-head-word-ID: 14
# target-entity-type: Activity
# target-entity: ['receive']
#
# source-head-sentence-ID: 5
# source-head-word-ID: 14
# source-entity-type: Activity
# source-entity: ['receive']
# target-head-sentence-ID: 6
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['If']
#
# source-head-sentence-ID: 6
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 6
# target-head-word-ID: 1
# target-entity-type: Condition Specification
# target-entity: ['the', 'request', 'is', 'not', 'finished', 'within', '30', 'days']
#
# source-head-sentence-ID: 6
# source-head-word-ID: 1
# source-entity-type: Condition Specification
# source-entity: ['the', 'request', 'is', 'not', 'finished', 'within', '30', 'days']
# target-head-sentence-ID: 6
# target-head-word-ID: 18
# target-entity-type: Activity
# target-entity: ['receives']
#
# source-head-sentence-ID: 6
# source-head-word-ID: 18
# source-entity-type: Activity
# source-entity: ['receives']
# target-head-sentence-ID: 6
# target-head-word-ID: 25
# target-entity-type: Activity
# target-entity: ['re-submit']
#
# source-head-sentence-ID: 6
# source-head-word-ID: 25
# source-entity-type: Activity
# source-entity: ['re-submit']
# target-head-sentence-ID: 0
# target-head-word-ID: 5
# target-entity-type: Activity
# target-entity: ['received']

# %% [markdown]
# ## Sentences around keyword

# %%
for doc_name in pet_reader.document_names:
    sentences = pet_reader.get_doc_sentences(doc_name)
    print(f" {doc_name} ".center(100, '-'))
    
    for i, s in enumerate(sentences):
        if 'if' in ' '.join([t.lower() for t in s]):
            
            #print(' '.join(sentences[max(i - 1, 0)]))
            print(i, ' '.join(s))
            #print(' '.join(sentences[min(i + 1, len(sentences) - 1)]))
# Out:
# --------------------------------------------- doc-5.4 ----------------------------------------------
# 6 If the supervisor rejects the report , the employee , who submitted it , is given a chance to edit it , for example to correct errors or better describe an expense .
# 7 If the supervisor approves the report , it goes to the treasurer .
# 9 If all is in order , the treasurer accepts the expenses for processing ( including , e.g . , payment or refund , and accounting ) .
# 10 If receipts are missing or do not match the report , he sends it back to the employee .
# 11 If a report returns to the employee for corrections , it must again go to a supervisor , even if the supervisor previously approved the report .
# 12 If the treasurer accepts the expenses for processing , the report moves to an automatic activity that links to a payment system .
# --------------------------------------------- doc-10.9 ---------------------------------------------
# 4 The MPO reports the implementation to the SP / PU / GO or notifies the SP / PU / GO about the failure of the changes .
# --------------------------------------------- doc-10.6 ---------------------------------------------
# -------------------------------------------- doc-10.14 ---------------------------------------------
# 0 If the MPOO sends the bill for the temporary continuation of the metering point operations to the GO , the GO examines the bill .
# 1 If the MSPO sends the bill for the temporary continuation of the measurement to the GO , the GO examines the bill .
# 2 If the MSPO sends the bill for additional readings to the GO , the GO examines the bill .
# 3 If the MPOO sends the bill for the equipment acquisition to the MPON or the GO , the MPON or the GO examines the bill .
# --------------------------------------------- doc-2.1 ----------------------------------------------
# 3 Then the problem report is compared to the customer SLA to identify what the extent and the details of the service degradation are .
# 5 An electronic service then determines the significance of the customer based on information that has been collected during the history of the contractual relationship .
# 7 In case the customer is of certain significance which would affect the counter measures previously decided upon , the process goes back to re-prioritize these measures otherwise the process continues .
# 13 If Service Management is sure they can analyze it , they perform the analysis and based on the outcome they create a trouble report that indicates the type of problem .
# 15 If no problems are detected , a notification about the normal service execution is created .
# 16 If a problem is detected this will be analyzed by Resource Provisioning and a trouble report is created .
# 17 Either trouble report or the normal execution notification will be included in a status report and sent back to Service Management .
# 33 Customer Service either receives the actual service performance ( if there was no problem ) or the problem resolution report .
# --------------------------------------------- doc-3.3 ----------------------------------------------
# 3 If the claim is marked as Not OK , it is sent back to the claims officer and the recommendation is repeated .
# 4 If the claim is OK , the claim handling process proceeds .
# --------------------------------------------- doc-6.1 ----------------------------------------------
# 2 In `` ACME Financial Accounting `` , a software specially developed for the ACME AG , she identifies the charging suppliers and creates a new instance ( invoice ) .
# 7 From it , the copy of the invoice is passed on to the next cost center manager , based on the docket , or if all items are marked correct , sent back to accounting .
# 9 However , if inconsistencies exist , e.g . because the ordered product is not of the expected quantity or quality , the cost center manager rejects the AP with a note and explanatory statement on the docket , and the copy of the invoice is sent back to accounting directly .
# 10 Based on the statements of the cost center managers , she will proceede with the clarification with the vendor , but , if necessary , she consults the cost center managers by telephone or e-mail again .
# 14 If the bill amount exceeds EUR 20 , the Board wants to check it again ( 4 - eyes-principle ) .
# --------------------------------------------- doc-3.7 ----------------------------------------------
# --------------------------------------------- doc-7.1 ----------------------------------------------
# 4 If someone is interested , he sends a note to the Manager .
# --------------------------------------------- doc-8.2 ----------------------------------------------
# 6 If the description is finally approved , I post the job .
# --------------------------------------------- doc-3.8 ----------------------------------------------
# 1 The Notification department at the car insurer checks the documents upon completeness and registers the claim .
# 4 If the assessment is positive , a garage is phoned to authorise the repairs and the payment is scheduled ( in this order ) .
# -------------------------------------------- doc-10.12 ---------------------------------------------
# 1 The INQ notifies the IP of the change .
# --------------------------------------------- doc-10.7 ---------------------------------------------
# --------------------------------------------- doc-8.1 ----------------------------------------------
# --------------------------------------------- doc-10.2 ---------------------------------------------
# 7 The GO informs the MPON about the failure of the overall transaction by deadline if after a maximum time limit no message of the MPON is present at the GO .
# 8 If the MPON informs the GO about the failure of the entire process , the GO confirms the failure of the assignment to the MPON .
# 9 If the MPON informs the GO about the successful completion of the overall process , the GO assigns the MPON .
# --------------------------------------------- doc-6.3 ----------------------------------------------
# 2 It optimizes our production processes and creates possibly uniform work packages so that the setup times are minimized .
# 6 Once all the data is present , we need to decide whether any parts are missing and must be procured or if this is not necessary .
# --------------------------------------------- doc-1.3 ----------------------------------------------
# 10 The waiter may wait to do the billing if he has another order to prepare or deliver .
# --------------------------------------------- doc-10.5 ---------------------------------------------
# --------------------------------------------- doc-4.1 ----------------------------------------------
# 33 The second intaker plans the first meeting only after the medical information of the physician if required has been received .
# --------------------------------------------- doc-8.3 ----------------------------------------------
# 5 Then I am available for clarifications , of course .
# --------------------------------------------- doc-2.2 ----------------------------------------------
# 19 If there are not any objections by the grid operator ( i.e . no supplier concurrence ) , customer service creates a CIS contract .
# --------------------------------------------- doc-5.1 ----------------------------------------------
# 2 If the loan is small and the customer is low risk , the loan is approved .
# 3 If the customer is high risk , the loan is denied .
# 4 If the customer needs further review or the loan amount is for $10,000 or more , the request is sent to the approver Web service .
# --------------------------------------------- doc-3.2 ----------------------------------------------
# 1 If some files are missing , a search is initiated , otherwise the files can be physically tracked to the intended location .
# --------------------------------------------- doc-10.3 ---------------------------------------------
# 1 The GO verifies the deregistration .
# 5 If the GO binds the MPOO to continue the operation , the MPOO confirmes the continuation to the MPOO .
# --------------------------------------------- doc-9.5 ----------------------------------------------
# 0 After the Expense Report is received , a new account must be created if the employee does not already have one .
# 5 If the request is not completed in 7 days , then the employee must receive an approval in progress email .
# 6 If the request is not finished within 30 days , then the process is stopped and the employee receives an email cancellation notice and must re-submit the expense report .
# --------------------------------------------- doc-9.2 ----------------------------------------------
# 1 If the customer calls or writes back declining the mortgage , the case details are updated and the work is then archived prior to cancellation .
# 2 If the customer sends back the completed offer documents and attaches all prerequisite documents then the case is moved to administration for completion .
# 3 If all pre-requisite documents are not provided a message is generated to the customer requesting outstanding documents .
# 4 If no answer is received after 2 weeks , the case details are updated prior to archive and cancellation .
# --------------------------------------------- doc-6.4 ----------------------------------------------
# 7 If this is not the case , we leave him alone , except if the potential project budget is huge .
# 9 If the customer is interested in the end , the next step is a detailed online presentation .
# 12 If we are not contacted within 2 weeks , a sales representative is calling the customer .
# --------------------------------------------- doc-3.1 ----------------------------------------------
# --------------------------------------------- doc-6.2 ----------------------------------------------
# --------------------------------------------- doc-5.3 ----------------------------------------------
# 3 If the request is rejected the process will end .
# 4 If the request is asked to make a change then it is returned to the petitioner / employee who can review the comments for the change request .
# 5 If the request is approved it will go to the purchase department that will be in charge of making quotations ( using a subprocess ) and select a vendor .
# 6 If the vendor is not valid in the system the purchase department will have to choose a different vendor .
# 8 In any case the system will send a notification to let the user know what the result was .
# 9 In any of the cases , approval , rejection or change required the system will send the user a notification .
# --------------------------------------------- doc-1.4 ----------------------------------------------
# -------------------------------------------- doc-10.13 ---------------------------------------------
# --------------------------------------------- doc-10.8 ---------------------------------------------
# 1 The GO verifies the deregistration .
# --------------------------------------------- doc-10.4 ---------------------------------------------
# 0 The MPON notifies the MPOO about equipment change intentions .
# 1 The MPOO announces self dismounting to the MPON or the MPOO shall notify the MPON about no self-dismounting of the MPOO .
# 8 The GO shall notify the MSP about the device changes , the master data , the meter count at dismounting , and the meter count at installation .
# --------------------------------------------- doc-9.4 ----------------------------------------------
# --------------------------------------------- doc-1.1 ----------------------------------------------
# 6 If the part is available in-house , it is reserved .
# 7 If it is not available , it is back-ordered .
# 10 If the storehouse has successfully reserved or back-ordered every item of the part list and the preparation activity has finished , the engineering department assembles the bicycle .
# --------------------------------------------- doc-1.2 ----------------------------------------------
# 1 If the customer decides that the costs are acceptable , the process continues , otherwise she takes her computer home unrepaired .
# 5 If an error is detected another arbitrary repair activity is executed , otherwise the repair is finished .
# -------------------------------------------- doc-10.11 ---------------------------------------------
# --------------------------------------------- doc-9.3 ----------------------------------------------
# 1 The Support Officer then checks the dates and suggests modifications .
# --------------------------------------------- doc-10.1 ---------------------------------------------
# --------------------------------------------- doc-5.2 ----------------------------------------------
# 3 If the request is rejected , the application is returned to the applicant / employee who can review the rejection reasons .
# 4 If the request is approved a notification is generated to the Human Resources Representative , who must complete the respective management procedures .
# -------------------------------------------- doc-10.10 ---------------------------------------------
# 3 If the MPO confirms the failure of the fault detector , he informes the GO and the MSP .
# --------------------------------------------- doc-3.6 ----------------------------------------------
# 1 If not , the claimant is informed that the claim must be rejected .
# 5 If the forms provide all relevant details , the claim is registered in the Claims Management system , which ends the Claims Notification process .
# --------------------------------------------- doc-3.5 ----------------------------------------------
# 5 If the mail is not compliant , a list of requisition explaining the reason for rejection is compiled and sent back to the party .
# --------------------------------------------- doc-9.1 ----------------------------------------------
# 1 If no new records are found , then the process should check the CRM system to see whether new returns have been filed .
# 2 If new returns exist , then register all defaulting accounts and customers .
# 3 If the defaulting client codes have not been previously advised , produce another table of defaulting accounts and send to account management .
# 4 All of this must be completed by 2 : 30 pm , if it is not , then an alert should be sent to the supervisor .
# 6 If new returns have been filed , reconcile with the existing account defaulters table .

# %% [markdown]
# ## Contradictory Gateways

# %%
same_gateway_relations = []
same_gateway_relations_doc_names = []
for doc_name in pet_reader.document_names:
    doc_relations = pet_reader.relations_dataset.GetRelations(pet_reader.get_document_number(doc_name))
    doc_same_gateway_relations = doc_relations[labels.SAME_GATEWAY]
    print(doc_name, len(doc_same_gateway_relations))
    same_gateway_relations.extend(doc_same_gateway_relations)
    same_gateway_relations_doc_names.extend([doc_name for i in range(len(doc_same_gateway_relations))])
# Out:
# doc-9.5 2
# doc-9.1 2
# doc-3.8 1
# doc-10.4 0
# doc-1.4 0
# doc-10.1 0
# doc-3.6 2
# doc-10.12 0
# doc-8.3 1
# doc-3.1 0
# doc-1.1 1
# doc-10.7 0
# doc-10.14 3
# doc-5.3 2
# doc-7.1 1
# doc-10.13 0
# doc-10.6 0
# doc-3.2 1
# doc-6.1 2
# doc-1.3 0
# doc-4.1 0
# doc-3.5 1
# doc-6.2 0
# doc-8.1 0
# doc-9.3 0
# doc-2.1 6
# doc-10.5 0
# doc-10.3 0
# doc-5.4 2
# doc-10.10 0
# doc-10.9 0
# doc-5.2 1
# doc-9.4 0
# doc-10.11 0
# doc-2.2 3
# doc-8.2 0
# doc-6.3 0
# doc-9.2 2
# doc-3.7 0
# doc-1.2 2
# doc-5.1 2
# doc-10.8 0
# doc-10.2 2
# doc-3.3 1
# doc-6.4 2

# %%
# GOLD PAIRS
contradictory_gateways = [(' '.join([t.lower() for t in sg[labels.SOURCE_ENTITY]]), 
                           ' '.join([t.lower() for t in sg[labels.TARGET_ENTITY]])) for sg in same_gateway_relations]
print(len(contradictory_gateways))
contradictory_gateways = sorted(list(set(contradictory_gateways)), key=lambda pair: pair[0])
print(len(contradictory_gateways))   

for a, b in contradictory_gateways:
    print(a, " | ", b)
# Out:
# 42
# 14
# either  |  or
# for the case  |  for the case
# if  |  otherwise
# if  |  if
# in case  |  in case
# in case  |  otherwise
# in case  |  if
# in case of  |  otherwise
# in case of  |  in case of
# in the case of  |  if
# otherwise  |  if
# should  |  if
# sometimes  |  sometimes
# under certain circumstances  |  otherwise

# %%
 with open(os.path.join(ROOT_DIR, 'data/keywords/contradictory_gateways_gold_new.txt'), 'w') as file:
        for pair in contradictory_gateways:
            file.write("%s\n" % f"{''.join(pair[0])};{''.join(pair[1])}")

# %%
print(len(same_gateway_relations))
for i, same_gateway_relation in enumerate(same_gateway_relations):
        for key, value in same_gateway_relation.items():
            print(f"{key}: {value}")
        print()
# Out:
# 42
# source-head-sentence-ID: 1
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 2
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['If']
#
# source-head-sentence-ID: 2
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 3
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['If']
#
# source-head-sentence-ID: 11
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['In', 'case', 'of']
# target-head-sentence-ID: 13
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['In', 'case', 'of']
#
# source-head-sentence-ID: 17
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['In', 'the', 'case', 'of']
# target-head-sentence-ID: 19
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['If']
#
# source-head-sentence-ID: 20
# source-head-word-ID: 19
# source-entity-type: XOR Gateway
# source-entity: ['either']
# target-head-sentence-ID: 20
# target-head-word-ID: 25
# target-entity-type: XOR Gateway
# target-entity: ['or']
#
# source-head-sentence-ID: 1
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 2
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['If']
#
# source-head-sentence-ID: 2
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 4
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['If']
#
# source-head-sentence-ID: 6
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 7
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['If']
#
# source-head-sentence-ID: 3
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 4
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['If']
#
# source-head-sentence-ID: 1
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 1
# target-head-word-ID: 11
# target-entity-type: XOR Gateway
# target-entity: ['otherwise']
#
# source-head-sentence-ID: 6
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 7
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['If']
#
# source-head-sentence-ID: 9
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 10
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['If']
#
# source-head-sentence-ID: 6
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['Should']
# target-head-sentence-ID: 9
# target-head-word-ID: 2
# target-entity-type: XOR Gateway
# target-entity: ['if']
#
# source-head-sentence-ID: 9
# source-head-word-ID: 2
# source-entity-type: XOR Gateway
# source-entity: ['if']
# target-head-sentence-ID: 10
# target-head-word-ID: 22
# target-entity-type: XOR Gateway
# target-entity: ['if']
#
# source-head-sentence-ID: 2
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['Sometimes']
# target-head-sentence-ID: 2
# target-head-word-ID: 9
# target-entity-type: XOR Gateway
# target-entity: ['sometimes']
#
# source-head-sentence-ID: 2
# source-head-word-ID: 9
# source-entity-type: XOR Gateway
# source-entity: ['sometimes']
# target-head-sentence-ID: 2
# target-head-word-ID: 18
# target-entity-type: XOR Gateway
# target-entity: ['sometimes']
#
# source-head-sentence-ID: 4
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 5
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['Otherwise']
#
# source-head-sentence-ID: 7
# source-head-word-ID: 14
# source-entity-type: XOR Gateway
# source-entity: ['if']
# target-head-sentence-ID: 8
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['If']
#
# source-head-sentence-ID: 8
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 9
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['If']
#
# source-head-sentence-ID: 4
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 6
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['Otherwise']
#
# source-head-sentence-ID: 3
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['Under', 'certain', 'circumstances']
# target-head-sentence-ID: 3
# target-head-word-ID: 11
# target-entity-type: XOR Gateway
# target-entity: ['otherwise']
#
# source-head-sentence-ID: 5
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 6
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['Otherwise']
#
# source-head-sentence-ID: 2
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 3
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['If']
#
# source-head-sentence-ID: 3
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 4
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['If']
#
# source-head-sentence-ID: 3
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 4
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['If']
#
# source-head-sentence-ID: 4
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 5
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['If']
#
# source-head-sentence-ID: 3
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['In', 'case', 'of']
# target-head-sentence-ID: 4
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['Otherwise']
#
# source-head-sentence-ID: 4
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['Otherwise']
# target-head-sentence-ID: 5
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['If']
#
# source-head-sentence-ID: 3
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 4
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['If']
#
# source-head-sentence-ID: 0
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 1
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['If']
#
# source-head-sentence-ID: 1
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 2
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['If']
#
# source-head-sentence-ID: 2
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 3
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['If']
#
# source-head-sentence-ID: 1
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 2
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['Otherwise']
#
# source-head-sentence-ID: 5
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 6
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['Otherwise']
#
# source-head-sentence-ID: 6
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['In', 'case']
# target-head-sentence-ID: 7
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['In', 'case']
#
# source-head-sentence-ID: 7
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['In', 'case']
# target-head-sentence-ID: 7
# target-head-word-ID: 26
# target-entity-type: XOR Gateway
# target-entity: ['otherwise']
#
# source-head-sentence-ID: 12
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['In', 'case']
# target-head-sentence-ID: 13
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['If']
#
# source-head-sentence-ID: 15
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 16
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['If']
#
# source-head-sentence-ID: 21
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['For', 'the', 'case']
# target-head-sentence-ID: 22
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['For', 'the', 'case']
#
# source-head-sentence-ID: 22
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['For', 'the', 'case']
# target-head-sentence-ID: 25
# target-head-word-ID: 0
# target-entity-type: XOR Gateway
# target-entity: ['For', 'the', 'case']
#
# source-head-sentence-ID: 1
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 1
# target-head-word-ID: 14
# target-entity-type: XOR Gateway
# target-entity: ['otherwise']
#
# source-head-sentence-ID: 5
# source-head-word-ID: 0
# source-entity-type: XOR Gateway
# source-entity: ['If']
# target-head-sentence-ID: 5
# target-head-word-ID: 12
# target-entity-type: XOR Gateway
# target-entity: ['otherwise']

# %%
# HOW OFTEN > 2 BRANCHES
print(len(len(same_gateway_relations)))
involved_gateways = {}
for sg, doc_name in zip(same_gateway_relations, same_gateway_relations_doc_names):
    g1 = f"{doc_name}-{sg[SOURCE_SENTENCE_ID]}-{sg[SOURCE_HEAD_TOKEN_ID]}-{sg[SOURCE_ENTITY]}"
    g2 = f"{doc_name}-{sg[TARGET_SENTENCE_ID]}-{sg[TARGET_HEAD_TOKEN_ID]}-{sg[TARGET_ENTITY]}"
    if g1 in involved_gateways:
        involved_gateways[g1] += 1
    else:
        involved_gateways[g1] = 1
    if g2 in involved_gateways:
        involved_gateways[g2] += 1
    else:
        involved_gateways[g2] = 1
            
involved_gateways = dict(sorted(involved_gateways.items(), key=lambda item: item[1], reverse=True))
for g, number in involved_gateways.items():
    print(g, number)
# Out:
# doc-9.5-4-0-['Otherwise'] 2
# doc-9.1-2-0-['If'] 2
# doc-10.14-1-0-['If'] 2
# doc-10.14-2-0-['If'] 2
# doc-5.3-4-0-['If'] 2
# doc-6.1-9-2-['if'] 2
# doc-2.1-7-0-['In', 'case'] 2
# doc-2.1-22-0-['For', 'the', 'case'] 2
# doc-9.2-2-0-['If'] 2
# doc-5.1-3-0-['If'] 2
# doc-10.2-8-0-['If'] 2
# doc-6.4-2-9-['sometimes'] 2
# doc-9.5-3-0-['In', 'case', 'of'] 1
# doc-9.5-5-0-['If'] 1
# doc-9.1-1-0-['If'] 1
# doc-9.1-3-0-['If'] 1
# doc-3.8-4-0-['If'] 1
# doc-3.8-5-0-['Otherwise'] 1
# doc-3.6-1-0-['If'] 1
# doc-3.6-2-0-['Otherwise'] 1
# doc-3.6-5-0-['If'] 1
# doc-3.6-6-0-['Otherwise'] 1
# doc-8.3-3-0-['Under', 'certain', 'circumstances'] 1
# doc-8.3-3-11-['otherwise'] 1
# doc-1.1-6-0-['If'] 1
# doc-1.1-7-0-['If'] 1
# doc-10.14-0-0-['If'] 1
# doc-10.14-3-0-['If'] 1
# doc-5.3-3-0-['If'] 1
# doc-5.3-5-0-['If'] 1
# doc-7.1-4-0-['If'] 1
# doc-7.1-6-0-['Otherwise'] 1
# doc-3.2-1-0-['If'] 1
# doc-3.2-1-11-['otherwise'] 1
# doc-6.1-6-0-['Should'] 1
# doc-6.1-10-22-['if'] 1
# doc-3.5-5-0-['If'] 1
# doc-3.5-6-0-['Otherwise'] 1
# doc-2.1-6-0-['In', 'case'] 1
# doc-2.1-7-26-['otherwise'] 1
# doc-2.1-12-0-['In', 'case'] 1
# doc-2.1-13-0-['If'] 1
# doc-2.1-15-0-['If'] 1
# doc-2.1-16-0-['If'] 1
# doc-2.1-21-0-['For', 'the', 'case'] 1
# doc-2.1-25-0-['For', 'the', 'case'] 1
# doc-5.4-6-0-['If'] 1
# doc-5.4-7-0-['If'] 1
# doc-5.4-9-0-['If'] 1
# doc-5.4-10-0-['If'] 1
# doc-5.2-3-0-['If'] 1
# doc-5.2-4-0-['If'] 1
# doc-2.2-11-0-['In', 'case', 'of'] 1
# doc-2.2-13-0-['In', 'case', 'of'] 1
# doc-2.2-17-0-['In', 'the', 'case', 'of'] 1
# doc-2.2-19-0-['If'] 1
# doc-2.2-20-19-['either'] 1
# doc-2.2-20-25-['or'] 1
# doc-9.2-1-0-['If'] 1
# doc-9.2-4-0-['If'] 1
# doc-1.2-1-0-['If'] 1
# doc-1.2-1-14-['otherwise'] 1
# doc-1.2-5-0-['If'] 1
# doc-1.2-5-12-['otherwise'] 1
# doc-5.1-2-0-['If'] 1
# doc-5.1-4-0-['If'] 1
# doc-10.2-7-14-['if'] 1
# doc-10.2-9-0-['If'] 1
# doc-3.3-3-0-['If'] 1
# doc-3.3-4-0-['If'] 1
# doc-6.4-2-0-['Sometimes'] 1
# doc-6.4-2-18-['sometimes'] 1

# %%
same_xor_gateway_threshold = 1

# DISTANCES BETWEEN RELATED GATEWAYS
sentence_distances_between = []
for sg in same_gateway_relations:
    print(abs(sg[SOURCE_SENTENCE_ID] - sg[TARGET_SENTENCE_ID]), abs(sg[SOURCE_SENTENCE_ID] - sg[TARGET_SENTENCE_ID]) > same_xor_gateway_threshold,
          sg[SOURCE_SENTENCE_ID], sg[TARGET_SENTENCE_ID])
    sentence_distances_between.append(abs(sg[SOURCE_SENTENCE_ID] - sg[TARGET_SENTENCE_ID]))
    

import statistics
print(statistics.mean(sentence_distances_between))
print(statistics.median(sentence_distances_between))
print(sentence_distances_between)
# Out:
# 1 False 3 4
# 1 False 4 5
# 1 False 1 2
# 1 False 2 3
# 1 False 4 5
# 1 False 1 2
# 1 False 5 6
# 0 False 3 3
# 1 False 6 7
# 1 False 0 1
# 1 False 1 2
# 1 False 2 3
# 1 False 3 4
# 1 False 4 5
# 2 True 4 6
# 0 False 1 1
# 3 True 6 9
# 1 False 9 10
# 1 False 5 6
# 1 False 6 7
# 0 False 7 7
# 1 False 12 13
# 1 False 15 16
# 1 False 21 22
# 3 True 22 25
# 1 False 6 7
# 1 False 9 10
# 1 False 3 4
# 2 True 11 13
# 2 True 17 19
# 0 False 20 20
# 1 False 1 2
# 2 True 2 4
# 0 False 1 1
# 0 False 5 5
# 1 False 2 3
# 1 False 3 4
# 1 False 7 8
# 1 False 8 9
# 1 False 3 4
# 0 False 2 2
# 0 False 2 2
# 1
# 1.0
# [1, 1, 1, 1, 1, 1, 1, 0, 1, 1, 1, 1, 1, 1, 2, 0, 3, 1, 1, 1, 0, 1, 1, 1, 3, 1, 1, 1, 2, 2, 0, 1, 2, 0, 0, 1, 1, 1, 1, 1, 0, 0]
